# %%
import pandas as pd

# %%
df = pd.read_csv("/home/juniorsilvadev/engenharia-dados/03-python-etl-do-basico-ao-avancado/Origem/Origem/arquivos_csv/Clientes.csv", delimiter=',')

# %%
df.head(5)
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
df['full_name'] = df['first_name'] + ' ' +df['last_name']
df.head(5)
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals  \
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %% [markdown]
# Adicionando um coluna com o ano

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df['year'] = df['created_at'].dt.year

# %%
df['month'] = df['created_at'].dt.month

# %%
df['day'] = df['created_at'].dt.day

# %%
df.head(5)
# Out:
#    id          created_at first_name last_name                email  \
# 0   0 2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1 2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2 2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3 2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4 2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals  \
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
ano2018 = df.loc[df['year'] == 2018]

# %%
ano2018.head(5)
# Out:
#    id          created_at first_name last_name                  email  \
# 2   2 2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 3   3 2018-01-17 03:02:58    Daniela   Avelino    daniela@exemplo.com
# 4   4 2018-08-06 07:24:16    Romário  Teixeira                    NaN
# 5   5 2018-01-05 17:20:49    Marcelo   Barroso                    NaN
# 6   6 2018-06-18 11:17:42  Cristiano    Elísio  cristiano@exemplo.com
#
#     cell_phone country              state                              street  \
# 2  9 5906-7552  Brasil          São Paulo      Avenida 59 do Estado São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso                                 NaN
# 4  9 3093-6522  Brasil              Bahia            Praça 56 do Estado Bahia
# 5  9 2830-2088  Brasil  Rio Grande do Sul  Rua 28 do Estado Rio Grande do Sul
# 6  9 3532-8404  Brasil              Goiás              Rua 78 do Estado Goiás
#
#    number  additionals         full_name  year  month  day
# ...

# %%
ano2018mes8 = df.loc[(df['year'] == 2018) & (df['month'] == 8)]

# %%
ano2018mes8.head(5)
# Out:
#     id          created_at first_name   last_name               email  \
# 4    4 2018-08-06 07:24:16    Romário    Teixeira                 NaN
# 13  13 2018-08-27 21:15:17   Carolina    Monteiro  carolina@teste.com
# 25  25 2018-08-07 12:22:40      Alice      Veloso   alice@exemplo.com
# 40  40 2018-08-17 13:21:08   Gabriela  Nascimento  gabriela@teste.com
# 50  50 2018-08-24 07:52:23    Beatriz    Monteiro   beatriz@teste.com
#
#      cell_phone country              state                             street  \
# 4   9 3093-6522  Brasil              Bahia           Praça 56 do Estado Bahia
# 13  9 1226-4267  Brasil  Rio Grande do Sul  Rua 4 do Estado Rio Grande do Sul
# 25  9 9869-3706  Brasil       Minas Gerais    Praça 73 do Estado Minas Gerais
# 40  9 5382-5772  Brasil              Amapá         Avenida 85 do Estado Amapá
# 50  9 3570-4464  Brasil       Minas Gerais  Avenida 17 do Estado Minas Gerais
#
#     number  additionals            full_name  year  month  day
# ...
