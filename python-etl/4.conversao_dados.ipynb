# %%
import pandas as pd
import os

# %%
df = pd.read_csv("/home/juniorsilvadev/engenharia-dados/python-etl/Origem/Origem/arquivos_csv/Clientes.csv")

# %%
df['id'].dtype
# Out:
# dtype('int64')

# %%
print(df['id'].dtype)
# Out:
# int64

# %%
for coluna in df.columns:
    print(f'Coluna: {coluna}, tipo de dados: {df[coluna].dtype}')
# Out:
# Coluna: id, tipo de dados: int64
# Coluna: created_at, tipo de dados: object
# Coluna: first_name, tipo de dados: object
# Coluna: last_name, tipo de dados: object
# Coluna: email, tipo de dados: object
# Coluna: cell_phone, tipo de dados: object
# Coluna: country, tipo de dados: object
# Coluna: state, tipo de dados: object
# Coluna: street, tipo de dados: object
# Coluna: number, tipo de dados: float64
# Coluna: additionals, tipo de dados: object

# %%
df['id'] = df['id'].astype(float)

# %%
print(df['id'].dtype)
# Out:
# float64

# %% [markdown]
# Conversão de Datas

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
print(df['created_at'].dtype)
# Out:
# datetime64[ns]

# %%
# Filtrar dados pelo intervalo entre 2008 a 2020
df_filtrado = df[(df['created_at'].dt.year >= 2008) & (df['created_at'].dt.year <= 2020)]
df_filtrado
# Out:
#       id          created_at first_name last_name                 email  \
# 0    0.0 2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1.0 2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2.0 2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3.0 2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4.0 2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..   ...                 ...        ...       ...                   ...
# 95  95.0 2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96.0 2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97.0 2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98.0 2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99.0 2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
# Filtrar somente o ano de 2018 e o mês de Janeiro
df_dt2 = df[(df['created_at'].dt.year == 2018) & df['created_at'].dt.month == 1]
df_dt2
# Out:
#       id          created_at first_name    last_name                   email  \
# 3    3.0 2018-01-17 03:02:58    Daniela      Avelino     daniela@exemplo.com
# 5    5.0 2018-01-05 17:20:49    Marcelo      Barroso                     NaN
# 9    9.0 2018-11-11 11:48:41       Luan         Dias        luan@exemplo.com
# 11  11.0 2018-05-16 03:39:52      James  Albuquerque                     NaN
# 12  12.0 2018-03-28 00:24:00      Carol      Barboza       carol@exemplo.com
# 15  15.0 2018-11-15 18:00:53  Stephanie      Barbosa   stephanie@usuario.com
# 24  24.0 2018-07-25 09:34:12       Jair      Barroso          jair@teste.com
# 27  27.0 2018-11-08 11:12:47       Luan         Lima          luan@teste.com
# 31  31.0 2018-07-02 22:04:08      Geisa      Freitas       geisa@exemplo.com
# 32  32.0 2018-07-22 11:59:27        Ana       Campos           ana@teste.com
# 36  36.0 2018-01-26 03:29:13    Mariana         Góes   mariana@meu_email.com
# ...

# %%
df['created_at'] = df['created_at'].dt.strftime('%d/%m/%Y %H:%M:%S')

# %%
df
# Out:
#       id           created_at first_name last_name                 email  \
# 0    0.0  01/11/2017 14:45:41      Marta     Jesus                   NaN
# 1    1.0  16/10/2017 00:50:39      Luana   Almeida                   NaN
# 2    2.0  16/06/2018 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3.0  17/01/2018 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4.0  06/08/2018 07:24:16    Romário  Teixeira                   NaN
# ..   ...                  ...        ...       ...                   ...
# 95  95.0  01/10/2018 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96.0  23/01/2018 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97.0  04/07/2018 18:45:41      Marta      Góes       marta@teste.com
# 98  98.0  24/01/2018 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99.0  24/07/2018 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %% [markdown]
# Convertendo data para o padrão BR no primeiro comando

# %%
# Convertendo a coluna created_at em formato de data e hora
df['created_at'] = pd.to_datetime(df['created_at'])

# Converter a data para o padrão brasileiro
df['created_at'] = df['created_at'].dt.strftime('%d/%m/%Y %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Convertendo a coluna created_at em formato de data e hora
# ----> 2 df['created_at'] = pd.to_datetime(df['created_at'])
#       4 # Converter a data para o padrão brasileiro
#       5 df['created_at'] = df['created_at'].dt.strftime('%d/%m/%Y %H:%M:%S')
#
# File ~/engenharia-dados/python-etl/venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...
