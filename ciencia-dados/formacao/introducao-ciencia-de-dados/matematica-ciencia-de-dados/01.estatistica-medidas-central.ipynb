# %%
import numpy as np
import pandas as pd

# %%
caminho = r'/home/juniorsilvadev/data-engineering-roadmap/ciencia-dados/formacao/introducao-ciencia-de-dados/matematica-ciencia-de-dados/enem_2019_tratado.csv'

# %%
enem_sp = pd.read_csv(caminho, sep=',', encoding='iso-8859-1')

# %%
print(enem_sp.head())
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL    RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1   parda
# 1     1,90E+11               São Paulo     17    F                1   parda
# 2     1,90E+11   São Bernardo do Campo     19    M                1   parda
# 3     1,90E+11              Embu-Guaçu     17    F                1   parda
# 4     1,90E+11               Guarulhos     23    F                1  branca
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0                 1                1  não_respondeu         NaN  ...   600.2
# 1                 1                2        privada  15567761.0  ...   731.8
# 2                 1                2        pública  35904958.0  ...   393.2
# 3                 1                2        pública         NaN  ...   419.2
# 4                 1                1  não_respondeu         NaN  ...   796.1
#
# ...

# %% [markdown]
# ## Média

# %%
enem_sp['IDADE'].mean()
# Out:
# np.float64(20.593387206464776)

# %%
enem_sp.IDADE.mean()
# Out:
# np.float64(20.593387206464776)

# %%
round(enem_sp['IDADE'].mean(),2)
# Out:
# np.float64(20.59)

# %%
enem_sp.NOTA_REDACAO.mean()
# Out:
# np.float64(593.0183221986639)

# %%
round(enem_sp.NOTA_REDACAO.mean(), 2)
# Out:
# np.float64(593.02)

# %% [markdown]
# ## Mediana

# %%
enem_sp['IDADE'].median()
# Out:
# np.float64(18.0)

# %%
enem_sp.NOTA_REDACAO.median()
# Out:
# np.float64(600.0)

# %%
enem_sp.NOTA_MT.median()
# Out:
# np.float64(511.8)

# %%
enem_sp.NOTA_CN.median()
# Out:
# np.float64(478.1)

# %%
enem_sp.NOTA_CH.median()
# Out:
# np.float64(523.7)

# %%
enem_sp.describe()
# Out:
#                IDADE  TP_ESTADO_CIVIL  TP_NACIONALIDADE  TP_ST_CONCLUSAO  \
# count  499940.000000    499940.000000     499940.000000    499940.000000
# mean       20.593387         1.053206          1.029902         1.476085
# std         6.465291         0.380866          0.230986         0.510351
# min        12.000000         0.000000          0.000000         1.000000
# 25%        17.000000         1.000000          1.000000         1.000000
# 50%        18.000000         1.000000          1.000000         1.000000
# 75%        21.000000         1.000000          1.000000         2.000000
# max        91.000000         4.000000          4.000000         4.000000
#
#           CO_ESCOLA  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# count  1.768940e+05        499940.0        499940.0        499940.0
# mean   3.521138e+07             1.0             1.0             1.0
# std    4.430392e+05             0.0             0.0             0.0
# ...

# %%
round(enem_sp.describe(), 2)
# Out:
#            IDADE  TP_ESTADO_CIVIL  TP_NACIONALIDADE  TP_ST_CONCLUSAO  \
# count  499940.00        499940.00         499940.00        499940.00
# mean       20.59             1.05              1.03             1.48
# std         6.47             0.38              0.23             0.51
# min        12.00             0.00              0.00             1.00
# 25%        17.00             1.00              1.00             1.00
# 50%        18.00             1.00              1.00             1.00
# 75%        21.00             1.00              1.00             2.00
# max        91.00             4.00              4.00             4.00
#
#          CO_ESCOLA  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# count    176894.00        499940.0        499940.0        499940.0
# mean   35211378.17             1.0             1.0             1.0
# std      443039.20             0.0             0.0             0.0
# min    11003065.00             1.0             1.0             1.0
# ...

# %% [markdown]
# ## Moda

# %%
enem_sp['IDADE'].mode()
# Out:
# 0    17
# Name: IDADE, dtype: int64

# %%
enem_sp.NOTA_REDACAO.mode()
# Out:
# 0    600.0
# Name: NOTA_REDACAO, dtype: float64

# %%
enem_sp.NOTA_MT.mode()
# Out:
# 0    433.8
# Name: NOTA_MT, dtype: float64

# %%
enem_sp.NOTA_CN.mode()
# Out:
# 0    481.8
# Name: NOTA_CN, dtype: float64

# %%
enem_sp.NOTA_CH.mode()
# Out:
# 0    0.0
# Name: NOTA_CH, dtype: float64

# %%
enem_sp.NOTA_LC.mode()
# Out:
# 0    55.2
# Name: NOTA_LC, dtype: float64

# %% [markdown]
# ## Distribuição

# %%
enem_sp.COMP3.mode()
# Out:
# 0    120.0
# Name: COMP3, dtype: float64

# %%
enem_sp.COMP3.mean()
# Out:
# np.float64(118.76069128295396)

# %%
enem_sp.COMP3.median()
# Out:
# np.float64(120.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 6))

# Cria o histograma
sns.histplot(enem_sp['COMP3'], bins=15, kde=False)

# Títulos
plt.title('Notas do componente 3 da redação - Enem SP 2019')
plt.xlabel('Nota COMP3')
plt.ylabel('Frequência')

plt.show()
