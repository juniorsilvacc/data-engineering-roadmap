# %%
import pandas as pd

# %%
tabela = pd.read_csv("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/arquivos_csv/Clientes.csv", delimiter=',')
tabela.head()
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
tabela = tabela.loc[tabela['state'] == 'São Paulo']

# %%
tabela
# Out:
#     id           created_at first_name last_name                  email  \
# 2    2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 20  20  2017-12-22 10:51:28  Adalberto     Silva  adalberto@usuario.com
# 59  59  2017-12-03 16:24:32  Stephanie    Freire  stephanie@usuario.com
# 78  78  2017-11-02 22:13:22      Laura   Queiroz      laura@exemplo.com
#
#      cell_phone country      state                          street  number  \
# 2   9 5906-7552  Brasil  São Paulo  Avenida 59 do Estado São Paulo   534.0
# 20  9 1338-1447  Brasil  São Paulo      Rua 57 do Estado São Paulo   851.0
# 59  9 3256-1853  Brasil  São Paulo      Rua 52 do Estado São Paulo    34.0
# 78  9 6338-8617  Brasil  São Paulo    Praça 19 do Estado São Paulo   878.0
#
#     additionals
# 2           NaN
# 20  Conjunto 20
# 59      Apto 24
# 78   Conjunto 3

# %%
estado = tabela.loc[tabela['state'] == 'Mato Grosso']

# %%
estado
# Out:
# Empty DataFrame
# Columns: [id, created_at, first_name, last_name, email, cell_phone, country, state, street, number, additionals]
# Index: []

# %%
estados = ['São Paulo', 'Mato Grosso', 'Ceará']
df_estados = tabela.loc[tabela['state'].isin(estados)]
df_estados
# Out:
#     id           created_at first_name last_name                  email  \
# 2    2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 20  20  2017-12-22 10:51:28  Adalberto     Silva  adalberto@usuario.com
# 59  59  2017-12-03 16:24:32  Stephanie    Freire  stephanie@usuario.com
# 78  78  2017-11-02 22:13:22      Laura   Queiroz      laura@exemplo.com
#
#      cell_phone country      state                          street  number  \
# 2   9 5906-7552  Brasil  São Paulo  Avenida 59 do Estado São Paulo   534.0
# 20  9 1338-1447  Brasil  São Paulo      Rua 57 do Estado São Paulo   851.0
# 59  9 3256-1853  Brasil  São Paulo      Rua 52 do Estado São Paulo    34.0
# 78  9 6338-8617  Brasil  São Paulo    Praça 19 do Estado São Paulo   878.0
#
#     additionals
# 2           NaN
# 20  Conjunto 20
# 59      Apto 24
# 78   Conjunto 3

# %%
tabela['street'] = tabela['street'].fillna('Não Cadastrado')
tabela['email'] = tabela['email'].fillna('Email Não Encontrado')
tabela['number'] = tabela['number'].fillna('Sem Número')
tabela['additionals'] = tabela['additionals'].fillna('Sem Informação')

# %%
tabela.head(10)
# Out:
#     id           created_at first_name last_name                  email  \
# 2    2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 20  20  2017-12-22 10:51:28  Adalberto     Silva  adalberto@usuario.com
# 59  59  2017-12-03 16:24:32  Stephanie    Freire  stephanie@usuario.com
# 78  78  2017-11-02 22:13:22      Laura   Queiroz      laura@exemplo.com
#
#      cell_phone country      state                          street  number  \
# 2   9 5906-7552  Brasil  São Paulo  Avenida 59 do Estado São Paulo   534.0
# 20  9 1338-1447  Brasil  São Paulo      Rua 57 do Estado São Paulo   851.0
# 59  9 3256-1853  Brasil  São Paulo      Rua 52 do Estado São Paulo    34.0
# 78  9 6338-8617  Brasil  São Paulo    Praça 19 do Estado São Paulo   878.0
#
#        additionals
# 2   Sem Informação
# 20     Conjunto 20
# 59         Apto 24
# 78      Conjunto 3

# %%
tabela['state'] = tabela['state'].replace('São Paulo', 'Sao Paulo')

tabela.head(10)
# Out:
#     id           created_at first_name last_name                  email  \
# 2    2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 20  20  2017-12-22 10:51:28  Adalberto     Silva  adalberto@usuario.com
# 59  59  2017-12-03 16:24:32  Stephanie    Freire  stephanie@usuario.com
# 78  78  2017-11-02 22:13:22      Laura   Queiroz      laura@exemplo.com
#
#      cell_phone country      state                          street  number  \
# 2   9 5906-7552  Brasil  Sao Paulo  Avenida 59 do Estado São Paulo   534.0
# 20  9 1338-1447  Brasil  Sao Paulo      Rua 57 do Estado São Paulo   851.0
# 59  9 3256-1853  Brasil  Sao Paulo      Rua 52 do Estado São Paulo    34.0
# 78  9 6338-8617  Brasil  Sao Paulo    Praça 19 do Estado São Paulo   878.0
#
#        additionals
# 2   Sem Informação
# 20     Conjunto 20
# 59         Apto 24
# 78      Conjunto 3

# %%
mapeamento = {'Goiás': 'Goias', 'Piauí': 'Piaui'}
tabela['state'] = tabela['state'].replace(mapeamento)

# %%
tabela.head(30)
# Out:
#     id           created_at first_name last_name                  email  \
# 2    2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 20  20  2017-12-22 10:51:28  Adalberto     Silva  adalberto@usuario.com
# 59  59  2017-12-03 16:24:32  Stephanie    Freire  stephanie@usuario.com
# 78  78  2017-11-02 22:13:22      Laura   Queiroz      laura@exemplo.com
#
#      cell_phone country      state                          street  number  \
# 2   9 5906-7552  Brasil  Sao Paulo  Avenida 59 do Estado São Paulo   534.0
# 20  9 1338-1447  Brasil  Sao Paulo      Rua 57 do Estado São Paulo   851.0
# 59  9 3256-1853  Brasil  Sao Paulo      Rua 52 do Estado São Paulo    34.0
# 78  9 6338-8617  Brasil  Sao Paulo    Praça 19 do Estado São Paulo   878.0
#
#        additionals
# 2   Sem Informação
# 20     Conjunto 20
# 59         Apto 24
# 78      Conjunto 3
