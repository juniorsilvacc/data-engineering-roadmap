# %%
import pandas as pd

# %%
df = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx")
display(df)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
# sheet_name -> Nome da planilha
# skiprows -> Pular linha
panilha02 = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx", sheet_name='Planilha2', skiprows=3)
display(panilha02)
# Out:
#               Loja  Vendas
# 0          Niterói     625
# 1         Curitiba     594
# 2   Rio de Janeiro     650
# 3        São Paulo     862
# 4           Cuiabá     452
# 5           Palmas     139
# 6         Teresina     175
# 7           Recife     293
# 8   Santa Catarina     529
# 9           Manaus     507
# 10  Belo Horizonte     705

# %%
# usecols -> Escolher coluna especifica
# nrows -> Definicar até onde quer selecionar
panilha03_1 = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx", sheet_name='Planilha3', usecols='A:B')
panilha03_2 = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx", sheet_name='Planilha3', usecols=[5,6])
display(panilha03_1, panilha03_2)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705
#               Loja  Vendas.1
# 0          Niterói       625
# 1         Curitiba       594
# 2   Rio de Janeiro       650
# 3        São Paulo       862
# 4           Cuiabá       452
# 5           Palmas       139
# 6         Teresina       175
# 7           Recife       293
# 8   Santa Catarina       529
# 9           Manaus       507
# 10  Belo Horizonte       705

# %%
panilha04 = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx", sheet_name='Planilha4', usecols='G:H', skiprows=7)
display(panilha04)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
panilha05_vendedor = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx", sheet_name='Planilha5', usecols='A:B', nrows=11)
panilha05_loja = pd.read_excel("/home/juniorsilvadev/engenharia-dados/python-etl/Arquivos Excel/arquivos_excel/Caquinha.xlsx", sheet_name='Planilha5', usecols='A:B', skiprows=13)
display(panilha05_vendedor, panilha05_loja)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705
#               Loja  Vendas
# 0          Niterói     625
# 1         Curitiba     594
# 2   Rio de Janeiro     650
# 3        São Paulo     862
# 4           Cuiabá     452
# 5           Palmas     139
# 6         Teresina     175
# 7           Recife     293
# 8   Santa Catarina     529
# 9           Manaus     507
# 10  Belo Horizonte     705
