# %%
import pandas as pd

# %%
# JSON
pasta_origem_json = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac.json"
df_json=pd.read_json(pasta_origem_json, orient="index")
df_json.head()
# Out:
#      id classificacao_da_ocorrencia  dt_da_ocorrencia      municipio  uf  \
# 0  7762                   Incidente     1521590400000      SÃO PAULO  SP
# 1  7759                    Acidente     1520985600000  MONTES CLAROS  MG
# 2  7758                    Acidente     1516924800000   INACIOLÂNDIA  GO
# 3  7758                    Acidente     1516924800000   INACIOLÂNDIA  GO
# 4  7757             Incidente Grave     1521331200000         TORRES  RS
#
#          regiao       fabricante     modelo
# 0       Sudeste           AGUSTA    AW109SP
# 1       Sudeste  CESSNA AIRCRAFT       A152
# 2  Centro-Oeste  CESSNA AIRCRAFT      T188C
# 3  Centro-Oeste  CESSNA AIRCRAFT      T188C
# 4           Sul   PIPER AIRCRAFT  PA-34-200

# %%
# CSV
pasta_origem_csv = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac.csv"
df_csv = pd.read_csv(pasta_origem_csv, sep=",")
df_csv.head()
# Out:
#      id classificacao_da_ocorrencia dt_da_ocorrencia      municipio  uf  \
# 0  7762                   Incidente       2018-03-21      SÃO PAULO  SP
# 1  7759                    Acidente       2018-03-14  MONTES CLAROS  MG
# 2  7758                    Acidente       2018-01-26   INACIOLÂNDIA  GO
# 3  7758                    Acidente       2018-01-26   INACIOLÂNDIA  GO
# 4  7757             Incidente Grave       2018-03-18         TORRES  RS
#
#          regiao       fabricante     modelo
# 0       Sudeste           AGUSTA    AW109SP
# 1       Sudeste  CESSNA AIRCRAFT       A152
# 2  Centro-Oeste  CESSNA AIRCRAFT      T188C
# 3  Centro-Oeste  CESSNA AIRCRAFT      T188C
# 4           Sul   PIPER AIRCRAFT  PA-34-200

# %%
# EXCEL
pasta_origem_excel = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac.xlsx"
df_excel = pd.read_excel(pasta_origem_excel)
df_excel.head()
# Out:
#      id classificacao_da_ocorrencia dt_da_ocorrencia      municipio  uf  \
# 0  7762                   Incidente       2018-03-21      SÃO PAULO  SP
# 1  7759                    Acidente       2018-03-14  MONTES CLAROS  MG
# 2  7758                    Acidente       2018-01-26   INACIOLÂNDIA  GO
# 3  7758                    Acidente       2018-01-26   INACIOLÂNDIA  GO
# 4  7757             Incidente Grave       2018-03-18         TORRES  RS
#
#          regiao       fabricante     modelo
# 0       Sudeste           AGUSTA    AW109SP
# 1       Sudeste  CESSNA AIRCRAFT       A152
# 2  Centro-Oeste  CESSNA AIRCRAFT      T188C
# 3  Centro-Oeste  CESSNA AIRCRAFT      T188C
# 4           Sul   PIPER AIRCRAFT  PA-34-200

# %%
# PARQUET
pasta_origem_parquet = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac.parquet"
df_parquet = pd.read_parquet(pasta_origem_parquet)
df_parquet.head()

#engine="pyarrow"
#engine="fastparquet"

# %%
# Parquet particionado
# pip install --upgrade pyarrow
# pip install --upgrade fastparquet

pasta_origem_parquet = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac_particonado.parquet"
df_parquet_particionado = pd.read_parquet(pasta_origem_parquet, engine = "fastparquet")
df_parquet_particionado.head()

# %%
# Parquet particionado somente uma partição e não um todo

pasta_origem_parquet_regiao = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac_particonado.parquet/Anac_particonado.parquet/regiao=Sudeste/uf=MG"
df_parquet_mg = pd.read_parquet(pasta_origem_parquet_regiao, engine = "fastparquet")
df_parquet_mg.head()

# %%
import os

pasta_principal = "/home/juniorsilvadev/engenharia-dados/engenharia-dados-com-python-e-banco-de-dados/PostgreSQL/5.Arquivos/Anac_particonado.parquet/Anac_particonado.parquet/regiao=Sudeste"
df_final = [] # df vazio para receber os dados

for pasta_regiao in os.listdir(pasta_principal):
    caminho_particao_estado = os.path.join(pasta_principal, pasta_regiao)      
    df_estado = pd.read_parquet(caminho_particao_estado, engine="fastparquet") 
    df_final.append(df_estado)


df_completo_sudeste = pd.concat(df_final, ignore_index=True)
df_completo_sudeste.head()
